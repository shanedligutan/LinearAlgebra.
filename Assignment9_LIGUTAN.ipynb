# %% [markdown]
# <a href="https://colab.research.google.com/github/shanedligutan/LinearAlgebra./blob/main/Assignment9_LIGUTAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Lab 2 - Plotting Vector using NumPy and MatPlotLib**

# %% [markdown]
# In this laboratory we will be discussing the basics of numerical and scientific programming by working with Vectors using NumPy and MatPlotLib.

# %% [markdown]
# ###**Objectives**

# %% [markdown]
# At the end of this activity you will be able to:
#
# 1. Be familiar with the libraries in Python for numerical and scientific programming.
# 2. Visualize vectors through Python programming.
# 3. Perform simple vector operations through code.

# %% [markdown]
# ###**Discussion**

# %% [markdown]
# ###**NumPy**

# %% [markdown]
# NumPy or Numerical Python, is mainly used for matrix and vector operations. It is capable of declaring computing and representing matrices. Most Python scientific programming libraries uses NumPy as the basic code.

# %% [markdown]
# NumPy is a Python library used for working with arrays. It is utilized for working in domain of linear algebra, fourier transform, and matrices. [1]
#
# ![1_cyXCE-JcBelTyrK-58w6_Q.png](data:image/png;base64,...)
# >Figure 1: Numpy Logo

# %% [markdown]
# Scalars \ Represent magnitude or a single value

# %% [markdown]
# Vectors \ Represent magnitude with directors

# %% [markdown]
# **Representing Vectors**

# %% [markdown]
# Now that you know how to represent vectors using their component and matrix form we can now hard-code them in Python. Let's say that you have the vectors:

# %% [markdown]
# $$ A = 4\hat{x} + 3\hat{y} \\
# B = 2\hat{x} - 5\hat{y}\\
# C = 4ax + 3ay - 2az \\
# D = 2\hat{i} - 2\hat{j} + 3\hat{k}$$

# %% [markdown]
# In which it's matrix equivalent is

# %% [markdown]
# $$ A = \begin{bmatrix} 4 \\ 3\end{bmatrix} , B = \begin{bmatrix} 2 \\ -5\end{bmatrix} , C = \begin{bmatrix} 4 \\ 3 \\  -2 \end{bmatrix}, D = \begin{bmatrix} 2 \\ -2 \\ 3\end{bmatrix}$$

# %% [markdown]
# We can then start doing numpy code with this by:

# %%
## Importing necessary libraries
import numpy as np ## 'np' here is short-hand name of the library (numpy) or a nickname.

# %%
A = np.array([4, 3])
B = np.array([2, -5])
C = np.array([
              [4],
              [3],
              [-2]
])
D = np.array ([[2],
              [-2],
              [3]])
print('Vector A is ', A)
print('Vector B is ', B)
print('Vector C is ', C)
print('Vector D is ', D)
# Out:
# Vector A is  [4 3]
# Vector B is  [ 2 -5]
# Vector C is  [[ 4]
#  [ 3]
#  [-2]]
# Vector D is  [[ 2]
#  [-2]
#  [ 3]]

# %% [markdown]
# **Describing vectors in NumPy**

# %% [markdown]
# Describing vectors is very important if we want to perform basic to advanced operations with them. The fundamental ways in describing vectors are knowing their shape, size and dimensions.

# %% [markdown]
# The multidimensional array is NumPy's primary data structure. We just make a one-dimensional array to make a vector. These arrays, like vectors, can be expressed horizontally (in rows) or vertically (in columns) (i.e., columns). [2]

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)
# ![Untitled1.png](data:image/png;base64,...)
# >Fig 2 and 3: The commands of describing Matrices is similar to Describing Vectors

# %%
### Checking shapes
### Shapes tells us how many elements are there on each row and column

A.shape
H = np.array([1, 0, 2, 5, -0.2, 0])
H.shape
C.shape
# Out:
# (3, 1)

# %%
### Checking size
### Array/Vector sizes tells us many total number of elements are there in the vector

D.size
# Out:
# 3

# %%
### Checking dimensions
### The dimensions or rank of a vector tells us how many dimensions are there for the vector.

D.ndim
# Out:
# 2

# %% [markdown]
# Great! Now let's try to explore in performing operations with these vectors.

# %% [markdown]
# **Addition**

# %% [markdown]
# The addition rule is simple, the we just need to add the elements of the matrices according to their index. So in this case if we add vector $A$ and vector $B$ we will have a resulting vector.

# %% [markdown]
# $$R = 6\hat{x}-2\hat{y} \\ \\or \\ \\ R = \begin{bmatrix} 6 \\ -2\end{bmatrix} $$

# %% [markdown]
# So let's try to do that in NumPy in several number of ways:

# %% [markdown]
# ![ss.png](data:image/png;base64,...)
# >Fig. 4: Matrix Operations are also similar to Vector Operations

# %% [markdown]
# The ND-array can be used to execute mathematical computations using an array's entries in mathematical expressions. When a function works on an array, NumPy applies the mathematical operation to each entry in the array. It is also similar to vector operations. [3]

# %%
R = np.add(A, B) ## this is the functional method using the numpy library
P = np.add(C, D)

# %%
R = A + B   ## this is the explicit method, since Python does a value-reference so it can 
            ## know that these variables would need to do array operations.
R
# Out:
# array([ 6, -2])

# %%
pos1 = np.array([0,0,0])
pos2 = np.array([0,1,3])
pos3 = np.array([1,5,-2])
pos4 = np.array([5,-3,3])
#R = pos1 + pos2 + pos3 + pos4
#R = np.multiply(pos3, pos4)
R = pos3 / pos4
R
# Out:
# array([ 0.2       , -1.66666667, -0.66666667])

# %% [markdown]
# ***Try for yourself***!

# %% [markdown]
# Try to implement subtraction, multiplication, and division with vectors $A$ and $B$!

# %%
R = A - B   
R
# Out:
# array([2, 8])

# %%
R = A * B   
R
# Out:
# array([  8, -15])

# %%
R = A / B   
R
# Out:
# array([ 2. , -0.6])

# %% [markdown]
# **Scaling**

# %% [markdown]
# Scaling or scalar multiplication takes a scalar value and performs multiplication with a vector. Let's take the example below:

# %% [markdown]
# $$S = 5 \cdot A$$

# %% [markdown]
# We can do this in numpy through:

# %%
#S = 5 * A
S = np.multiply(5,A)
S
# Out:
# array([20, 15])

# %% [markdown]
# Try to implement scaling with two vectors.

# %% [markdown]
# **MatPlotLib**

# %% [markdown]
# MatPlotLib or MATLab Plotting library is Python's take on MATLabs plotting feature. MatPlotLib can be used vastly from graping values to visualizing several dimensions of data.

# %% [markdown]
# matplotlib.pyplot is a set of functions that allows matplotlib to behave similarly to MATLAB. Each pyplot function modifies a figure in some way, such as creating a figure, a plotting area in a figure, charting certain lines in a plotting area, decorating the plot with labels, and so on. [4]

# %% [markdown]
# **Visualizing Data**

# %% [markdown]
# It's not enough just solving these vectors so might need to visualize them. So we'll use MatPlotLib for that. We'll need to import it first.

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
A = [1, -1]
B = [5, -1]
plt.scatter(A[0], A[1], label='A', c='green')
plt.scatter(B[0], B[1], label='B', c='magenta')
plt.grid()
plt.legend()
plt.show()

# %%
A = np.array([1, -1])
B = np.array([1, 5])
plt.title("Resultant Vector\nMagnitude:{}")
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='red')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
R = A + B
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R**2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [2 4]
# 4.47213595499958
# 2.0
# 63.43494882292201

# %%
n = A.shape[0]
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.quiver(0,0, A[0], A[1], angles='xy', scale_units='xy',scale=1)
plt.quiver(A[0],A[1], B[0], B[1], angles='xy', scale_units='xy',scale=1)
plt.quiver(0,0, R[0], R[1], angles='xy', scale_units='xy',scale=1)
plt.show()

# %% [markdown]
# Try plotting Three Vectors and show the Resultant Vector as a result.
# Use Head to Tail Method.

# %%
A = np.array([0, 4])
B = np.array([2, 1])
C = np.array([3, 3])
plt.title("Resultant Vector\nMagnitude:{}")
plt.xlim(-5, 10)
plt.ylim(-5, 10)
plt.quiver(0, 0, A[0], A[1], angles='xy', scale_units='xy', scale=1, color='yellow')
plt.quiver(A[0], A[1], B[0], B[1], angles='xy', scale_units='xy', scale=1, color='green')
plt.quiver(2, 5, C[0], C[1], angles='xy', scale_units='xy', scale=1, color='blue')
R = A + B + C
plt.quiver(0, 0, R[0], R[1], angles='xy', scale_units='xy', scale=1, color='black')
plt.grid()
plt.show()
print(R)
Magnitude = np.sqrt(np.sum(R**2))
print(Magnitude)
Slope = R[1]/R[0]
print(Slope)
Angle = (np.arctan(Slope))*(180/np.pi)
print(Angle)
# Out:
# [5 8]
# 9.433981132056603
# 1.6
# 57.9946167919165

# %% [markdown]
# **Conclusion**

# %% [markdown]
# The numpy operation provides different methods for matrix and vector operations. From our previous lab experiment, we tackled about arrays and matrix operations. Vectors and Matrices are similar, as it is commonly used in mathematical and scientific calculations for important data structures. A vector can be represented using their component in a matrix form so we can utilize them in Python. Just like a matrix, vectors are also represented by numbers, strings, and expressions. These data can be utilized in various operations in adding, subtracting, multiplying, and dividing. With the numpy library, we can perform numerical calculations with Python.
# Python has Matplotlib that allows you to have a visual representation of vectors. The use of vectorization allows numpy to perform more efficiently. Vectors are quantities that include both magnitude and direction. Vector Field, in simple terms, is the engagement or collaboration of such vectors in a subset of space. Vector fields are crucial to comprehending our real-world surroundings.
